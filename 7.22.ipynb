# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## score 1

# %%
df_1 = pd.read_csv(r'C:\Users\priya\Downloads\score1_data.csv')

# %%
df_1.head()
# Out:
#    Label  PixelCount  Area  Perimeter  Circularity  EulerNumber  Box.X.Min  \
# 0      1        1692  1692    204.479        0.509            1         42
# 1      2           9     9     11.051        0.926            1        179
# 2      3           3     3      6.474        0.900            1        191
# 3      4         197   197     85.730        0.337            1        251
# 4      5        1081  1081    156.846        0.552            1        323
#
#    Box.X.Max  Box.Y.Min  Box.Y.Max  ...  OBox.Length  OBox.Width  \
# 0        103          0         37  ...        61.00      37.000
# 1        182          0          4  ...         4.00       3.000
# 2        192          0          3  ...         3.00       1.000
# 3        277          0         16  ...        26.00      16.000
# 4        369          0         37  ...        46.51      35.688
#
#    OBox.Orientation  GeodesicDiameter  Tortuosity  InscrDisc.Center.X  \
# ...

# %%
selected_B_from_1 = [0, 42, 50, 4, 236, 261]
selected_C_from_1 =[31, 21]

# %%
# Combine the row indices to drop
rows_to_drop = selected_B_from_1 + selected_C_from_1
# Drop those rows and concatenate
df_A = df_1.drop(index=rows_to_drop)

# %%
df_A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399 entries, 1 to 406
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Label                399 non-null    int64
#  1   PixelCount           399 non-null    int64
#  2   Area                 399 non-null    int64
#  3   Perimeter            399 non-null    float64
#  4   Circularity          399 non-null    float64
#  5   EulerNumber          399 non-null    int64
#  6   Box.X.Min            399 non-null    int64
#  7   Box.X.Max            399 non-null    int64
#  8   Box.Y.Min            399 non-null    int64
#  9   Box.Y.Max            399 non-null    int64
#  10  Centroid.X           399 non-null    float64
#  11  Centroid.Y           399 non-null    float64
#  12  Ellipse.Center.X     399 non-null    float64
#  13  Ellipse.Center.Y     399 non-null    float64
#  14  Ellipse.Radius1      399 non-null    float64
# ...

# %%
df_B = df_1.iloc[selected_B_from_1]

# %%
df_C = df_1.iloc[selected_C_from_1]

# %% [markdown]
# ## score 2

# %%
df_2 = pd.read_csv(r'C:\Users\priya\Downloads\score2_data.csv')

# %%
selected_B_from_2 = [20, 0, 23, 8, 26, 69, 71, 125, 105, 8, 23]
selected_C_from_2 = [36]

# %%
rows_to_drop = selected_B_from_2 + selected_C_from_2
df_A = pd.concat([df_A, df_2.drop(index=rows_to_drop)])
df_B = pd.concat([df_B, df_2.iloc[selected_B_from_2]])
df_C = pd.concat([df_C, df_2.iloc[selected_C_from_2]])

# %% [markdown]
# ## score 3

# %%
df_3 = pd.read_csv(r'C:\Users\priya\Downloads\score3-lbl-Morphometry.csv')

# %%
selected_A_from_3 = [16,17, 19, 20, 14, 49, 53, 47, 33, 26, 37, 21, 40, 31, 44, 55, 50, 89,99, 114, 127, 125,58,64,68,69,77,85,82,90,94, 59, 60, 62, 96, 101, 123]
selected_B_from_3 = [29,19,36,39,12, 32, 33, 18, 28, 50, 54, 74, 70, 72, 97, 98, 102, 107, 116, 113, 125]
selected_C_from_3 = [23,15,42,52,117]

df_A = pd.concat([df_A, df_3.iloc[selected_A_from_3]])
df_B = pd.concat([df_B, df_2.iloc[selected_B_from_3]])
df_C = pd.concat([df_C, df_2.iloc[selected_C_from_3]])

# %% [markdown]
# ## score 4

# %%
df_4 = pd.read_csv(r'C:\Users\priya\Downloads\score4.csv')

# %%
selected_A_from_4 = [29,28,24,23, 58, 55, 55, 103, 97, 115, 116, 118, 76, 110]
selected_B_from_4 = [0, 3,4,7,8,12,21,32,34,30,36,43,40,43,39,37,54,52,63,70,68,74,58,72,79,93, 108, 111,102,101,106,113,118,117,86,79,72,19, 10, 13, 25]
selected_C_from_4= [85, 87, 71, 109, 104, 94]

df_A = pd.concat([df_A, df_4.iloc[selected_A_from_4]])
df_B = pd.concat([df_B, df_4.iloc[selected_B_from_4]])
df_C = pd.concat([df_C, df_4.iloc[selected_C_from_4]])

# %% [markdown]
# ## score 5

# %%
df_5 = pd.read_csv(r'C:\Users\priya\Downloads\score5_data.csv')

# %%
selected_A_from_5 = []
selected_B_from_5 = [5,9,6, 36]
selected_C_from_5= [0,1,15,17,13, 23, 34, 42,49, 37, 51, 57, 54, 62, 67, 71, 76, 78]
selected_D_from_5= [3, 51]

df_B = pd.concat([df_B, df_5.iloc[selected_B_from_5]])
df_C = pd.concat([df_C, df_5.iloc[selected_C_from_5]])
df_D = df_5.iloc[selected_D_from_5]

# %% [markdown]
# ## score 6

# %%
df_6 = pd.read_csv(r"C:\Users\priya\Downloads\score6_data.csv")

# %%
selected_D_from_6= [1,2,3]

df_D = pd.concat([df_D, df_6.iloc[selected_D_from_6]])

# %%
df_A.to_csv("df_A.csv", index=False)
df_B.to_csv("df_B.csv", index=False)
df_C.to_csv("df_C.csv", index=False)

# %%
df_D.to_csv("df_D.csv", index = False)

# %% [markdown]
# ## Ugly Pellets

# %%
df_7 = pd.read_csv(r"C:\Users\priya\Downloads\big_ugly_pellets.csv")

# %%
selected_C_from_7= [118, 102, 91, 78, 137]
selected_D_from_7= [5, 50, 123, 137, 96, 113]

# %%
df_C = pd.concat([df_C, df_7.iloc[selected_D_from_7]])
df_D = pd.concat([df_D, df_7.iloc[selected_D_from_7]])

# %% [markdown]
# ## like20clumps

# %%
df_8 = pd.read_csv(r"C:\Users\priya\Downloads\like20clumps.csv")

# %%
selected_C_from_8 = [1, 7, 8, 6, 9, 12, 13, 15, 17, 16, 22, 29, 30, 28, 26, 24, 19, 14, 11]
df_C = pd.concat([df_C, df_8.iloc[selected_C_from_8]])

# %% [markdown]
# ## Weird Glare Pellets with weird lumps around it

# %%
df_9 = pd.read_csv(r"C:\Users\priya\Downloads\Screenshot2025-07-21170053-lbl-Morphometry.csv")

# %%
selected_D_from_9 = [0, 5, 10, 15]
df_D = pd.concat([df_D, df_9.iloc[selected_D_from_9]])

# %% [markdown]
# ## clumps again i guess

# %%
df_10 = pd.read_csv(r"C:\Users\priya\Downloads\Screenshot2025-07-21170129-lbl-Morphometry.csv")

# %%
selected_C_from_10 = [0, 1, 3, 5, 13, 21, 25, 27, 14, 20, 15, 10, 37, 36, 29, 38, 31, 28, 39, 49, 50, 51, 45, 43, 56, 61, 63, 52, 54, 71, 76, 73, 70, 81, 82, 80, 86, 90, 87, 88, 94]
df_C = pd.concat([df_C, df_10.iloc[selected_C_from_10]])

# %% [markdown]
# ## Pellets and Clumps

# %%
df_11 = pd.read_csv(r"C:\Users\priya\Downloads\Screenshot2025-07-21170151-lbl-Morphometry.csv")

# %%
selected_B_from_11 = [18]
selected_C_from_11= [0, 2, 5, 10, 11, 12, 14, 19, 22, 20, 23, 25]
selected_D_from_11= [7, 1, 3]

df_B = pd.concat([df_B, df_11.iloc[selected_B_from_11]])
df_C = pd.concat([df_C, df_11.iloc[selected_C_from_11]])
df_D = pd.concat([df_D, df_11.iloc[selected_D_from_11]])

# %% [markdown]
# ## Lots of awesome clumps

# %%
df_12 = pd.read_csv(r"C:\Users\priya\Downloads\Screenshot2025-07-21170226-lbl-Morphometry.csv")

# %%
selected_A_from_12 = [2, 4, 12]
selected_B_from_12 = [27, 44, 38]
selected_C_from_12= [11, 10, 7, 3, 15, 20, 18, 22, 23, 26, 31, 30, 34, 39, 35, 36, 40, 42]


df_A = pd.concat([df_A, df_12.iloc[selected_A_from_12]])
df_B = pd.concat([df_B, df_12.iloc[selected_B_from_12]])
df_C = pd.concat([df_C, df_12.iloc[selected_C_from_12]])

# %% [markdown]
# ## 3 pellets

# %%
df_13 = pd.read_csv(r"C:\Users\priya\Downloads\Screenshot2025-07-21170237-lbl-Morphometry.csv")

# %%
selected_B_from_13 = [30, 37]
selected_D_from_13= [16, 51]

df_B = pd.concat([df_B, df_13.iloc[selected_B_from_13]])
df_D = pd.concat([df_D, df_13.iloc[selected_D_from_13]])

# %% [markdown]
# ## Second to last one

# %%
df_14 = pd.read_csv(r"C:\Users\priya\Downloads\Screenshot2025-07-21170237-lbl-Morphometry.csv")

# %%
selected_B_from_14 = [23, 28, 19, 24, 26, 27]
selected_C_from_14= [6, 15, 18, 32, 9, 8, 13, 7, 33, 34, 1, 0, 5, 2, 16, 20, 29, 22, 34]


df_B = pd.concat([df_B, df_14.iloc[selected_B_from_14]])
df_C = pd.concat([df_C, df_14.iloc[selected_C_from_14]])

# %% [markdown]
# ## Last One

# %%
df_15 = pd.read_csv(r"C:\Users\priya\Downloads\Screenshot2025-07-21170555-lbl-Morphometry.csv")

# %%
selected_B_from_15 = [12]
selected_C_from_15= [0, 3, 4, 16, 22, 20, 7, 13]
selected_D_from_15= [2]


df_B = pd.concat([df_B, df_15.iloc[selected_B_from_15]])
df_C = pd.concat([df_C, df_15.iloc[selected_C_from_15]])
df_D = pd.concat([df_D, df_15.iloc[selected_D_from_15]])

# %% [markdown]
# ## Extra Filtering

# %%
df_A = df_A[df_A['PixelCount'] > 50]
df_B = df_B[df_B['PixelCount'] > 50]
df_C = df_C[df_C['PixelCount'] > 50]

# %%
for df in [df_A, df_B, df_C, df_D]:
    df["Solidity"] = df["Area"] / df["ConvexArea"]

# %% [markdown]
# # Data Processing and Analysis

# %%
from scipy.stats import gaussian_kde

def create_three_graphs(dfA, dfB, dfC, dfD, column_name, save_dir=None):
    colors = ["steelblue", "seagreen", "orchid", 'red']
    pdList = [dfA, dfB, dfC, dfD]
    titles = ["A", "B", "C", "D"]
    
    # Compute global x range
    global_df = pd.concat(pdList)
    filtered_df = global_df[global_df[column_name].notna()]
    
    if filtered_df.empty:
        print(f"❌ No data found for column '{column_name}'.")
        return
    
    all_column = filtered_df[column_name]
    x_min, x_max = all_column.min(), all_column.max()

       # Compute y_max using actual histogram heights (density=True)
    y_max = 0
    for df in pdList:
        subset = df[column_name].dropna()
        if len(subset) > 1:
            counts, _ = np.histogram(subset, bins=20, density=True)
            y_max = max(y_max, counts.max())

    # Add margin
    y_limit = y_max * 1.1 if y_max > 0 else 0.1


    # Create subplots
    fig, axes = plt.subplots(1, 4, figsize=(20, 9), sharex=True, sharey=True)

    for ax, df, color, title in zip(axes, pdList, colors, titles):
        subset = df[column_name].dropna()
        if len(subset) == 0:
            ax.set_visible(False)
            continue

        ax.hist(
            subset,
            bins=20,
            color=color,
            edgecolor="black",
            density=True
        )
        ax.set_xlim(x_min, x_max)
        ax.set_ylim(0, y_limit)
        ax.set_title(f"{title}: {column_name}", fontsize=17)
        ax.set_xlabel(column_name)

    axes[0].set_ylabel("Proportion")
    plt.tight_layout()

    if save_dir:
        plt.savefig(f"{save_dir}/{column_name}_comparison.png", dpi=300)
        print(f"✅ Saved to {save_dir}/{column_name}_comparison.png")

    plt.show()


def generate_summary(dfA, dfB, dfC, dfD, column_name):
    pdList = [dfA, dfB, dfC, dfD]
    titles = ["A", "B", "C", "D"]

    for title, df in zip(titles, pdList):
        print(f"\n{title}: {column_name}")
        if column_name in df.columns:
            summary = df[column_name].describe().round(2)
            print(summary.to_frame(name=column_name))
        else:
            print(f"⚠️ Column '{column_name}' not found in DataFrame {title}.")


def generate_all_summaries(dfA, dfB, dfC, dfD):
    pdList = [dfA, dfB, dfC, dfD]
    titles = ["A", "B", "C", "D"]

    # Find common numeric columns
    common_cols = set(dfA.columns)
    for df in pdList[1:]:
        common_cols &= set(df.columns)
    numeric_cols = [col for col in common_cols if pd.api.types.is_numeric_dtype(dfA[col])]

    print("📊 Summary statistics for all common numeric columns:\n")

    for col in sorted(numeric_cols):
        print(f"\n🔹 {col}:\n")
        summary_df = pd.DataFrame()

        for title, df in zip(titles, pdList):
            if col in df.columns:
                summary = df[col].describe().round(2)
                summary_df[title] = summary

        display(summary_df.T)  # Use IPython display if in notebook; or use print below if not
        # print(summary_df.T.to_string())  # Uncomment if running in plain script

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def generate_all_histograms(dfA, dfB, dfC, dfD, save_dir=None):
    pdList = [dfA, dfB, dfC, dfD]
    titles = ["A", "B", "C", "D"]
    colors = ["steelblue", "seagreen", "orchid", "red"]

    # Find common numeric columns
    common_cols = set(dfA.columns)
    for df in pdList[1:]:
        common_cols &= set(df.columns)
    numeric_cols = [col for col in common_cols if pd.api.types.is_numeric_dtype(dfA[col])]

    print("📊 Generating histograms for all common numeric columns:\n")

    for col in sorted(numeric_cols):
        print(f"📈 Plotting: {col}")

        # Combine to get x-axis range
        global_df = pd.concat(pdList)
        filtered = global_df[col].dropna()
        if filtered.empty:
            print(f"⚠️ Skipping {col} (no data)")
            continue
        x_min, x_max = filtered.min(), filtered.max()

        # Compute dynamic y_max (proportion-based)
        y_max = 0
        for df in pdList:
            values = df[col].dropna()
            if len(values) > 1:
                counts, _ = np.histogram(values, bins=20, density=True)
                y_max = max(y_max, counts.max())
        y_limit = y_max * 1.1 if y_max > 0 else 0.1

        # Create 1x4 subplot
        fig, axes = plt.subplots(1, 4, figsize=(20, 5), sharex=True, sharey=True)

        for ax, df, title, color in zip(axes, pdList, titles, colors):
            subset = df[col].dropna()
            if len(subset) == 0:
                ax.set_visible(False)
                continue

            ax.hist(
                subset,
                bins=20,
                density=True,
                color=color,
                edgecolor="black",
                alpha=0.8
            )
            ax.set_title(f"{title}", fontsize=15)
            ax.set_xlabel(col)
            ax.set_xlim(x_min, x_max)
            ax.set_ylim(0, y_limit)

        axes[0].set_ylabel("Proportion")
        plt.suptitle(f"{col} Comparison", fontsize=18)
        plt.tight_layout(rect=[0, 0, 1, 0.95])

        if save_dir:
            filename = f"{save_dir}/{col}_histogram.png"
            plt.savefig(filename, dpi=300)
            print(f"✅ Saved: {filename}")

        plt.show()

# %% [markdown]
# # ANALYSIS

# %%
generate_all_histograms(df_A, df_B, df_C, df_D)
# Out:
# 📊 Generating histograms for all common numeric columns:
#
# 📈 Plotting: Area
# 📈 Plotting: AverageThickness
# 📈 Plotting: Box.X.Max
# 📈 Plotting: Box.X.Min
# 📈 Plotting: Box.Y.Max
# 📈 Plotting: Box.Y.Min
# 📈 Plotting: Centroid.X
# 📈 Plotting: Centroid.Y
# 📈 Plotting: Circularity
# 📈 Plotting: ConvexArea
# 📈 Plotting: Convexity
# 📈 Plotting: Ellipse.Center.X
# 📈 Plotting: Ellipse.Center.Y
# 📈 Plotting: Ellipse.Elong
# 📈 Plotting: Ellipse.Orientation
# 📈 Plotting: Ellipse.Radius1
# 📈 Plotting: Ellipse.Radius2
# 📈 Plotting: EulerNumber
# 📈 Plotting: GeodesicDiameter
# 📈 Plotting: GeodesicElongation
# 📈 Plotting: InscrDisc.Center.X
# 📈 Plotting: InscrDisc.Center.Y
# 📈 Plotting: InscrDisc.Radius
# 📈 Plotting: Label
# 📈 Plotting: MaxFeretDiam
# 📈 Plotting: MaxFeretDiamAngle
# 📈 Plotting: OBox.Center.X
# 📈 Plotting: OBox.Center.Y
# 📈 Plotting: OBox.Length
# 📈 Plotting: OBox.Orientation
# 📈 Plotting: OBox.Width
# 📈 Plotting: Perimeter
# 📈 Plotting: PixelCount
# 📈 Plotting: Solidity
# ...

# %%
generate_all_summaries(df_A, df_B, df_C, df_D)
# Out:
# 📊 Summary statistics for all common numeric columns:
#
#
# 🔹 Area:
#    count      mean       std   min      25%     50%       75%      max
# A  213.0    304.58    299.42  51.0   122.00   206.0    342.00   1883.0
# B   80.0    835.44    855.18  52.0   486.75   675.0   1051.00   7161.0
# C  132.0   2368.29   5496.97  71.0   305.00   510.0   1702.25  34463.0
# D   21.0  10337.95  10624.18  85.0  1793.00  6254.0  15048.00  34463.0
# 🔹 AverageThickness:
#    count   mean    std   min    25%    50%    75%    max
# A  213.0   5.73   2.48  1.78   3.84   5.33   7.10  15.32
# B   80.0   8.65   3.69  1.67   5.54   9.21  10.83  17.16
# C  132.0  15.74  11.78  4.35   7.92  12.45  19.13  70.19
# D   21.0  37.95  22.58  1.22  21.77  32.57  55.81  79.48
# 🔹 Box.X.Max:
#    count    mean     std   min     25%    50%     75%    max
# A  213.0  271.62  149.65  13.0  145.00  262.0  403.00  526.0
# B   80.0  247.76  136.99  15.0  141.75  225.0  370.25  496.0
# ...
